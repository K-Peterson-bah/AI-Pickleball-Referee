# %%
from ultralytics import YOLO

# %%
model = YOLO("models/yolo11n-pose.pt")
model = model.to("cuda")

# %%
import torch
torch.cuda.empty_cache()

# %%
results = model.train(data="./Data/court_data/data.yaml", epochs=150,
                batch=16, imgsz=1280, patience=5, mosaic=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.151 available  Update with 'pip install -U ultralytics'
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.147  Python-3.12.6 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 8188MiB)
# YOLO11n-pose summary (fused): 109 layers, 2,766,703 parameters, 0 gradients, 7.0 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 53.611.4 MB/s, size: 184.3 KB)
# val: Scanning C:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\Data\court_data\valid\labels.cache... 57 images, 0 backgrounds, 0 corrupt: 100%|██████████| 57/57 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:07<00:00,  1.88s/it]
#                    all         57         57      0.996          1      0.995      0.806      0.979      0.982       0.98      0.549
# Speed: 17.7ms preprocess, 11.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\pose\train32

# %%
model2 = YOLO("./models/yolo11n-pose.pt")
model2 = model2.to("cuda")
torch.cuda.empty_cache()

# %%
model2.train(data="./Data/court_data_v2/data.yaml", epochs=150,
                batch=16, imgsz=1280, patience=8, mosaic=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.151 available  Update with 'pip install -U ultralytics'
# ...

# %%
model3 = YOLO("./models/yolo11s-pose.pt")
model3 = model3.to("cuda")
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 model3 = YOLO("./models/yolo11s-pose.pt")
# ----> 2 model3 = model3.to("cuda")
#       3 torch.cuda.empty_cache()
#
# File c:\Users\kpete\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1355, in Module.to(self, *args, **kwargs)
#    1352         else:
#    1353             raise
# -> 1355 return self._apply(convert)
#
# File c:\Users\kpete\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:877, in Model._apply(self, fn)
#     855 """
#     856 Apply a function to model tensors that are not parameters or registered buffers.
#     857
#    (...)
#     874     >>> model = model._apply(lambda t: t.cuda())  # Move model to GPU
#     875 """
#     876 self._check_is_pytorch_model()
# --> 877 self = super()._apply(fn)  # noqa
# ...

# %%
model3.train(data="./Data/court_data_v2/data.yaml", epochs=150,
                batch=16, imgsz=1280, patience=5, mosaic=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.152 available  Update with 'pip install -U ultralytics'
# ...

# %% [markdown]
# # Model Testing

# %%
test_model = YOLO("./runs/pose/train3/weights/best.pt")

# %%
test_model.predict(source="./videos/vid1.mp4", save=True, conf=.7)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1833) c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\videos\vid1.mp4: 736x1280 1 courts, 64.7ms
# video 1/1 (frame 2/1833) c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\videos\vid1.mp4: 736x1280 1 courts, 65.3ms
# video 1/1 (frame 3/1833) c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\videos\vid1.mp4: 736x1280 1 courts, 61.1ms
# ...
