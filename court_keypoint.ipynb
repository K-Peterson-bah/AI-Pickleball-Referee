# %%
from ultralytics import YOLO

# %%
model = YOLO("models/yolo11n-pose.pt")
model = model.to("cuda")

# %%
import torch
torch.cuda.empty_cache()

# %%
results = model.train(data="./Data/court_data_v3/data.yaml", epochs=150,
                batch=16, imgsz=1280, patience=5, mosaic=0.0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.153 available  Update with 'pip install -U ultralytics'
# ...

# %% [markdown]
# # Model Testing

# %%
test_model = YOLO("./runs/pose/train9/weights/best.pt")

# %%
test_model.val()

# %%
test_model.predict(source="./videos/vid2.mp4", save=True, conf=.9)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1750) c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\videos\vid2.mp4: 736x1280 (no detections), 55.6ms
# video 1/1 (frame 2/1750) c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\videos\vid2.mp4: 736x1280 (no detections), 76.6ms
# ...

# %%
res = test_model("./Data/court_data_v3/test/images/shuffled_0_frame_006328.png")
keypoints = res[0].keypoints
print(keypoints)
# Out:
# image 1/1 c:\Users\kpete\OneDrive\Desktop\DataSciencePortfolio\AI-Pickleball-Referee\Data\court_data_v3\test\images\shuffled_0_frame_006328.png: 736x1280 1 court skeleton, 164.7ms
# Speed: 14.2ms preprocess, 164.7ms inference, 4.1ms postprocess per image at shape (1, 3, 736, 1280)
# ultralytics.engine.results.Keypoints object with attributes:
#
# conf: tensor([[0.9997, 0.9997, 0.9998, 0.9997, 0.9997, 0.9996, 0.9997, 0.9997, 0.9994, 0.9291, 0.9997, 0.8578]], device='cuda:0')
# data: tensor([[[4.9894e+02, 1.1808e+02, 9.9974e-01],
#          [6.5457e+02, 1.1697e+02, 9.9971e-01],
#          [8.1159e+02, 1.1591e+02, 9.9975e-01],
#          [4.4574e+02, 1.8671e+02, 9.9974e-01],
#          [6.5449e+02, 1.8519e+02, 9.9972e-01],
#          [8.6482e+02, 1.8493e+02, 9.9965e-01],
#          [3.5824e+02, 3.0588e+02, 9.9971e-01],
#          [6.5376e+02, 3.0684e+02, 9.9967e-01],
#          [3.6000e+02, 3.0542e+02, 9.9941e-01],
#          [9.5317e+01, 6.4750e+02, 9.2914e-01],
# ...
